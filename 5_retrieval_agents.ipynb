# %% [markdown]
# ## Basic Retrieval with DuckDuckGo
# Let's build a simple agent that can search the web using DuckDuckGo. This agent will retrieve information and synthesize responses to answer queries. With Agentic RAG, Alfred's agent can:
#
# Search for latest superhero party trends
# Refine results to include luxury elements
# Synthesize information into a complete plan
# Here's how Alfred's agent can achieve this:

# %%
from smolagents import CodeAgent, DuckDuckGoSearchTool, HfApiModel

# Initialize the search tool
search_tool = DuckDuckGoSearchTool()

# Initialize the model
model = HfApiModel()

agent = CodeAgent(
    model = model,
    tools=[search_tool]
)

# Example usage
response = agent.run(
    "Search for luxury superhero-themed party ideas, including decorations, entertainment, and catering."
)
print(response)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Search for luxury superhero-themed party ideas, including decorations, entertainment, and catering.             │
# │                                                                                                                 │
# ╰─ HfApiModel - Qwen/Qwen2.5-Coder-32B-Instruct ──────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   results = web_search(query="luxury superhero-themed party ideas")
#   print(results)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [24 Superhero Party Ideas that Will Make You Wish You Were a
# Kid](https://howdoesshe.com/24-incredible-superhero-party-ideas-that-will-make-you-wish-you-were-a-kid-again/)
# Let your superman show his own superpowers!Kids (and even adults) who love superheroes will fall in love with these
# incredible superhero theme party ideas that will bring out the kid in everyone! From decor ideas, party foods, and
# costume ideas to superhero-themed activities and superhero games, we have different ways to cover all of your party
# needs. These ideas will make you wish you were a ...
#
# [15 Superhero Birthday Party Ideas for an Epic Celebration - This Makes
# That](https://thismakesthat.com/superhero-birthday-party-ideas/)
# Create superhero-themed bingo cards for a fun and interactive party game. Laser Maze Challenge Participants
# navigate through a maze of laser beams, pretending to avoid detection by the enemy, adding an element of excitement
# to the superhero-themed party.
#
# [Elegant superhero party - Pinterest](https://www.pinterest.com/ideas/elegant-superhero-party/919813378132/)
# Find and save ideas about elegant superhero party on Pinterest.
#
# [25 Superhero Party Ideas For All Ages](https://playideas.com/25-superhero-party-ideas/)
# These super cool superhero theme party ideas are so much fun and perfect for all ages! Boy, girl, teen, or adult,
# it doesn't matter. They are perfect for your next superhero-themed food and party! We have found some amazingly
# fantastic party ideas from treats, decor, crafts to souvenirs for different sorts of superheroes, from Batman,
# Super ...
#
# [The Best Superhero Party Ideas For An Epic Party - Smart Party
# Planning](https://smartpartyplanning.com/superhero-party-ideas/)
# Awesome superhero party ideas that will have your kids showing off their superhero powers in no time at all. With
# ideas for decorations, food and party games you will easily win the status of superhero mom. These ideas can be
# achieved on a budget with a bit of DIY. The kids are going to love them. Related articles: 5 Awesome Batman Party
# Ideas
#
# [Superhero theme party for adults -
# Pinterest](https://www.pinterest.com/ideas/superhero-theme-party-for-adults/916708620865/)
# Find and save ideas about superhero theme party for adults on Pinterest.
#
# [Check out These Fantastic 14 Must-See Superhero Party
# Ideas!](https://www.catchmyparty.com/blog/14-must-see-superhero-party-ideas)
# Superhero parties have always been a huge hit with kids. Movies like Iron-man, Batman, Avengers, and so many more
# have made the theme the mega success it is. So, if you have a little boy or a young man dying for a superhero
# party, you won't want to miss these 14 must-see superhero party ideas.
#
# [Mini Party Plan: How to Plan a Superhero Birthday
# Party](https://thepartyteacher.com/2018/08/23/mini-party-plan-superhero-party/)
# One of the most popular posts on this blog is a girl's superhero party. So I thought it might be fun to create a
# mini party plan for a superhero birthday party. I styled this mini party plan in the traditional red, yellow, and
# blue, but you could change the color palette for a more girly pink and purple superhero party, if you prefer.
#
# [By a Pro: Superhero Party Ideas by a Professional](https://party-ideas-by-a-pro.com/party-themes/superhero-party/)
# Patriotic 4th of July recipes can easily be repurposed as Captain America themed Superhero party food, such as
# these recipes for Red, White, and Blue Chocolate Dipped Strawberries (below left, by Nicole at Baking Bites) or
# Jell-O cut into star shapes (below right, by Ali from Gimme Some Oven).
#
# [Best Superhero Party Theme Ideas - Captain
# Fantastic](https://captain-fantastic.co.uk/blog/best-superhero-party-theme-ideas/)
# Superhero Party Theme Ideas Superhero Costume Extravaganza: Dress as Your Favorite Hero. Gear up for the ultimate
# adventure at the Superhero Costume Extravaganza - a pinnacle in the realm of excitement. Dive into the magic as you
# and your guests transform into beloved heroes, unleashing a world of imagination. Whether you don the cape of a ...
#
# Out: None
# [Step 0: Duration 3.69 seconds| Input tokens: 2,086 | Output tokens: 50]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   url1 =
#   "https://howdoesshe.com/24-incredible-superhero-party-ideas-that-will-make-you-wish-you-were-a-kid-again/"
#   url4 = "https://playideas.com/25-superhero-party-ideas/"
#   page1 = web_search(query=url1)
#   page4 = web_search(query=url4)
#   print("Page 1:\n", page1)
#   print("="*80)
#   print("Page 4:\n", page4)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Page 1:
#  ## Search Results
#
# [24 Superhero Party Ideas that Will Make You Wish You Were a
# Kid](https://howdoesshe.com/24-incredible-superhero-party-ideas-that-will-make-you-wish-you-were-a-kid-again/)
# These ideas will make you wish you were a kid again and it was your birthday or a special day. If you are willing
# to arrange your own superhero party, here are some great ideas for your themed party. Try some for your little
# superhero's next party! 24 Incredible Superhero Party Ideas! 1. Condiments and beverages that really "POP!" 2.
#
# [24 Incredible Superhero Party Ideas that Will Make You Wish You Were a
# ...](https://www.pinterest.com/pin/24-incredible-superhero-party-ideas-that-will-make-you-wish-you-were-a-kid-
#
# [Superhero Party Ideas | PartyWizz Blog](https://partywizz.com/blog/family/party-ideas/superhero-party-ideas/)
# Hiring a professional face painter is guaranteed to add another layer of excitement to your superhero party.
# Whether your mini-caped crusaders want to emulate Superman with a bold 'S' symbol, channel their inner web-slinger
# with a detailed spider design or acquire a Wonder Woman-style headband, a skilled face painting artist will delight
# ...
#
# [The 15 Best Superhero Games for a Birthday Party - Frugal Coupon
# Living](https://www.frugalcouponliving.com/best-superhero-games/)
# Choose from icebreaker games, party games, and fun superhero activities that will make your event one to remember.
# Below are some ideas for superhero games that will make your party go off with a bang! Target Practice: The best
# superheroes need sharp throwing skills, and this game will help get you into shape to fight even the toughest
# villain ...
#
# Out: None
# [Step 2: Duration 30.07 seconds| Input tokens: 10,922 | Output tokens: 372]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 4 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # Searching for detailed luxury superhero-themed party ideas on reputable sources
#   luxury_party_ideas = web_search(query="luxury superhero-themed party ideas official site")
#   print(luxury_party_ideas)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [By a Pro: Superhero Party Ideas by a Professional](https://party-ideas-by-a-pro.com/party-themes/superhero-party/)
# Superhero party ideas by an award winning professional party planner including ideas for invitations, party food &
# drinks, decorations, and party supplies. ... Patriotic 4th of July recipes can easily be repurposed as Captain
# America themed Superhero party food, such as these recipes for Red, White, and Blue Chocolate Dipped Strawberries
# ...
#
# [25 Superhero Party Ideas For All Ages](https://playideas.com/25-superhero-party-ideas/)
# These super cool superhero theme party ideas are so much fun and perfect for all ages! Boy, girl, teen, or adult,
# it doesn't matter. They are perfect for your next superhero-themed food and party! We have found some amazingly
# fantastic party ideas from treats, decor, crafts to souvenirs for different sorts of superheroes, from Batman,
# Super ...
#
# [15 Ideas for Superhero-Themed Events -
# BizBash](https://www.bizbash.com/catering-design/event-design-decor/media-gallery/13479192/15-ideas-for-superheroth
# emed-events)
# New York's Robin Hood Foundation, which hosts one of the largest and most successful benefits in the city, tapped
# contacts at DC Comics to help create a superhero theme for its 2011 gala. The planning and design team created an
# emblem and slogan—"the forces of good are gathering"—that marked the night's invite and main cocktail area.
#
# [Superhero-Themed Party Ideas & Decorations |
# CORKCICLE.](https://corkcicle.com/blogs/lifestyle/marvel-themed-party-ideas)
# Superhero-themed parties have become a beloved trend, offering an exciting way to celebrate special occasions. The
# thrill of donning capes and masks, the vibrant decorations, and the heroic atmosphere make these parties a hit
# among kids and adults alike. In this guide, we'll explore Marvel superhero party ideas, ensuring your celebration
# is as epic as the comics and movies themselves ...
#
# [The Best Superhero Party Ideas For An Epic Party - Smart Party
# Planning](https://smartpartyplanning.com/superhero-party-ideas/)
# It is always recommended to have a party backdrop behind your food table. This backdrop can also be used as a photo
# booth. Choose 3 colors to create the backdrop. If you don't want to create your own backdrop, you could purchase a
# skyline scene setter.. An easy way to give instant superhero appeal is to create buildings either on the food table
# or around the party area.
#
# [24 Superhero Party Ideas that Will Make You Wish You Were a
# Kid](https://howdoesshe.com/24-incredible-superhero-party-ideas-that-will-make-you-wish-you-were-a-kid-again/)
# Let your superman show his own superpowers!Kids (and even adults) who love superheroes will fall in love with these
# incredible superhero theme party ideas that will bring out the kid in everyone! From decor ideas, party foods, and
# costume ideas to superhero-themed activities and superhero games, we have different ways to cover all of your party
# needs. These ideas will make you wish you were a ...
#
# [15 Superhero Birthday Party Ideas for an Epic Celebration - This Makes
# That](https://thismakesthat.com/superhero-birthday-party-ideas/)
# Create superhero-themed bingo cards for a fun and interactive party game. Laser Maze Challenge Participants
# navigate through a maze of laser beams, pretending to avoid detection by the enemy, adding an element of excitement
# to the superhero-themed party.
#
# [Best Superhero Party Theme Ideas - Captain
# Fantastic](https://captain-fantastic.co.uk/blog/best-superhero-party-theme-ideas/)
# Superhero Party Theme Ideas Superhero Costume Extravaganza: Dress as Your Favorite Hero. Gear up for the ultimate
# adventure at the Superhero Costume Extravaganza - a pinnacle in the realm of excitement. Dive into the magic as you
# and your guests transform into beloved heroes, unleashing a world of imagination. Whether you don the cape of a ...
#
# [Superhero Party Ideas - FUN365](https://www.fun365.orientaltrading.com/article/superhero-party-ideas)
# These fun superhero party ideas will have your guests inspired and impressed with your party's theme! Skip Header &
# Navigation Skip to Footer Navigation. All content on this site is available, via phone, at 1-877-513-0369. . If you
# experience any accessibility issues ...
#
# [Superheroes Party Ideas - Catch My Party](https://www.catchmyparty.com/party-ideas/superheroes)
# Superheroes Party Products Superhero Personalized Plate - Polymer Comic Styling - Custom Plate for Boy - Microwave
# Dishwasher Oven Safe - Lasts for Years! $25.00
#
# Out: None
# [Step 3: Duration 15.44 seconds| Input tokens: 19,119 | Output tokens: 511]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 5 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # Searching for detailed luxury superhero-themed party ideas on official sites
#   luxury_party_ideas = web_search(query="luxury elegant superhero-themed party ideas")
#   print(luxury_party_ideas)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [Elegant superhero party - Pinterest](https://www.pinterest.com/ideas/elegant-superhero-party/919813378132/)
# Find and save ideas about elegant superhero party on Pinterest.
#
# [By a Pro: Superhero Party Ideas by a Professional](https://party-ideas-by-a-pro.com/party-themes/superhero-party/)
# Patriotic 4th of July recipes can easily be repurposed as Captain America themed Superhero party food, such as
# these recipes for Red, White, and Blue Chocolate Dipped Strawberries (below left, by Nicole at Baking Bites) or
# Jell-O cut into star shapes (below right, by Ali from Gimme Some Oven).
#
# [Top 10 High-end Party Themes: From Concept to
# Celebration](https://luxuryleisureaffluence.com/high-end-party-themes/)
# Transport your guests to a magical Arabian oasis with this opulent and exotic high-end party theme. From sumptuous
# fabrics to ornate cushions and low-seating arrangements such as pouffes and ottomans, every detail will exude
# grandeur and elegance. Create a luxurious atmosphere with vibrant colours, intricate patterns, and lavish decor
# elements worthy of Middle Eastern royalty.
#
# [The Very Best Luxury Party Themes - Mirage Parties](https://mirageparties.co.uk/blog/a-to-z-luxury-party-themes/)
# Planning a Themed Party? As a themed party planner with more than 25 years of expertise we deliver authenticity,
# innovation and high production values to the world of high-end private parties. We'd love to show you our full
# portfolio. Do get in touch. Call 01883 740400 or email info@mirageparties.co.uk. A to Z 100+ Luxury Party Themes
#
# [Elegant Batman Themed Party Ideas For Adults - Entertaining
# Diva](https://www.entertainingdiva.com/batman-party-ideas/)
# It's that sense of nostalgia and a deep-seated love for the Dark Knight that made me decide to throw a
# Batman-themed party for Halloween. But since it was a party for adults, I wanted it to be an elegant and
# sophisticated super hero celebration. Not one that was too cartoon-ish.
#
# [24 Superhero Party Ideas that Will Make You Wish You Were a
# Kid](https://howdoesshe.com/24-incredible-superhero-party-ideas-that-will-make-you-wish-you-were-a-kid-again/)
# Let your superman show his own superpowers!Kids (and even adults) who love superheroes will fall in love with these
# incredible superhero theme party ideas that will bring out the kid in everyone! From decor ideas, party foods, and
# costume ideas to superhero-themed activities and superhero games, we have different ways to cover all of your party
# needs. These ideas will make you wish you were a ...
#
# [Superheroes Party Ideas - Themes for Parties](https://www.themesforparties.com.au/character/superheroes/)
# Have theme related games like an Indiana Jones Treasure hunt or a Heroes vs. Villains tug-of-war. Superheroes Food
# Ideas. Superhero comics and movies are usually eye catching with lots of bright colours. Use food colouring and
# lollies to make your party food just as colourful. For Green Goblin salad, use plenty of lettuce, spinach, cucumber
# and ...
#
# [30+ Superhero Party Ideas - Canva](https://www.canva.com/ideas/superhero-party-ideas/)
# Browse a wide range of superhero party ideas and inspiration, from photos and templates in a stunning selection of
# styles and colours. ... all these ingenious concepts and more are in our special selection of superhero-themed
# designs and photos. Have a quick browse and find some excellent ideas for your party! Yellow Blue Red Superhero
# Pattern ...
#
# [Superheroes & Princesses Themed Party Ideas -
# pepper-play.com](https://pepper-play.com/blog/superheroes-princesses-themed-party-ideas/)
# Incorporate princess-themed elements in the clues and decorations to enhance the magical atmosphere. Royal Tea
# Party: Set up a tea party station with elegant teacups, saucers, and a variety of teas. Encourage the young
# princesses to enjoy a refined tea party experience, complete with finger foods and delightful desserts. Princess
# Dance Party:
#
# [Superhero-Themed Party Ideas & Decorations |
# CORKCICLE.](https://corkcicle.com/blogs/lifestyle/marvel-themed-party-ideas)
# Superhero-themed parties have become a beloved trend, offering an exciting way to celebrate special occasions. The
# thrill of donning capes and masks, the vibrant decorations, and the heroic atmosphere make these parties a hit
# among kids and adults alike. In this guide, we'll explore Marvel superhero party ideas, ensuring your celebration
# is as epic as the comics and movies themselves ...
#
# Out: None
# [Step 4: Duration 11.87 seconds| Input tokens: 28,568 | Output tokens: 633]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 6 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # Extract details from the relevant URLs
#   url1 = "https://www.pinterest.com/ideas/elegant-superhero-party/919813378132/"
#   url2 = "https://party-ideas-by-a-pro.com/party-themes/superhero-party/"
#   url3 = "https://www.entertainingdiva.com/batman-party-ideas/"
#
#   # Fetching content from the selected URLs
#   content1 = web_search(query=url1)
#   content2 = web_search(query=url2)
#   content3 = web_search(query=url3)
#
#   # Printing the fetched content
#   print("Content from URL 1:", content1)
#   print("="*80)
#   print("Content from URL 2:", content2)
#   print("="*80)
#   print("Content from URL 3:", content3)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
#
# 2. **Face Painting and Photo Booth:** Set up a photo booth with superhero backdrop prints and have a professional face painter on-site.
# 3. **Interactive Games:** Organize games like a laser maze challenge or a "Superhero Training Camp" with agility courses.
# 4. **DJ or Live Music:** Hire a DJ or a live band to provide an epic soundtrack throughout the event, complete with superhero-themed sound effects.
#
# #### Catering:
# 1. **Superhero-Themed Food Stations:** Include gourmet hot dogs and chicken nuggets shaped like superhero symbols, Gotham-themed cocktails, and elegant finger foods like chicken satay, shrimp cocktail, and pulled pork sliders.
# 2. **Custom Desserts:** Order custom cakes resembling iconic superheroes (e.g., Batman silhouette, Wonder Woman emblem) or create signature drinks like Gotham Grapes (vodka and grape juice) or the Laser Beam (white wine with a splash of red).
# 3. **DIY Cocktail Bars:** Set up a DIY cocktail bar where guests can mix their own cocktails using superhero-themed mixers and syrups.
# 4. **Special Treats:** Offer adult-themed treats, such as superhero-themed brownies or a vodka/comic book bar.
#
# #### Specific Luxury Superhero-Themed Party Ideas
#
# ### 1. **Batman Party for Adults**
#    - **Decorations:** Gotham City backdrop, neon lighting, dark theme with accented red and yellow.
#    - **Entertainment:** Live acrobatics, professional actors, and Batman-themed photo booth with props.
#    - **Catering:** Gotham Grapes cocktail, Dark Knight gourmet tray, and Batman-inspired cupcakes.
#
# ### 2. **Superhero Masquerade Ball**
#    - **Decorations:** Luxe ballroom decor with black and silver accents, elaborate chandeliers, and red carpet entry.
#    - **Entertainment:** Live performance by acrobats in superhero costumes, masked guests, and a live orchestra.
#    - **Catering:** Custom hors d'oeuvres, luxe cocktails, and gourmet superhero-themed sweets.
#
# ### 3. **Captain America Red, White, and Blue Gala**
#    - **Decorations:** Patriotic-themed decor with red and white strreamers, gold accents, and a backdrop of the American flag.
#    - **Entertainment:** Live band with patriotic songs, a live show featuring acrobatics and patriotic themes, and a photo booth with hero and villain props.
#    - **Catering:** Red, white, and blue themed gourmet cocktails, Apple slices in star shapes (with blue frosting), and Jello shots shaped like stars.
#
# ### 4. **Avengers Crossover Party**
#    - **Decorations:** Collaborate with multiple superheroes, creating a dynamic mix of styles for each hero.
#    - **Entertainment:** Live actors from different superhero teams, special effects, and welfare zone activities like "Guardian of the Galaxy," "Avengers Training."
#    - **Catering:** Avengers-themed cocktails, hero food (iron man steel-plated sushi, Captain America’s Shield-shaped sliders, Vision’s Grilled Cheese and Tomato Soup cups).
#
# These luxury superhero-party ideas should help create an unforgettable evening, blending high-end elegance with the excitement of the superhero world.

# %% [markdown]
# The agent follows this process:
#
# 1) Analyzes the Request: Alfred’s agent identifies the key elements of the query—luxury superhero-themed party planning, with focus on decor, entertainment, and catering.
# 2) Performs Retrieval: The agent leverages DuckDuckGo to search for the most relevant and up-to-date information, ensuring it aligns with Alfred’s refined preferences for a luxurious event.
# 3) Synthesizes Information: After gathering the results, the agent processes them into a cohesive, actionable plan for Alfred, covering all aspects of the party.
# 4) Stores for Future Reference: The agent stores the retrieved information for easy access when planning future events, optimizing efficiency in subsequent tasks

# %% [markdown]
# ## Custom Knowledge Base Tool
# For specialized tasks, a custom knowledge base can be invaluable. Let's create a tool that queries a vector database of technical documentation or specialized knowledge. Using semantic search, the agent can find the most relevant information for Alfred's needs.
#
# This approach combines predefined knowledge with semantic search to provide context-aware solutions for event planning. With specialized knowledge access, Alfred can perfect every detail of the party.
#
# Install the dependecies first and run!

# %%
#!pip install langchain-community rank_bm25
# !pip install 'smolagents[litellm]'
# Out:
# Requirement already satisfied: smolagents[litellm] in ./playground/lib/python3.10/site-packages (1.9.2)
# Requirement already satisfied: huggingface-hub>=0.28.0 in ./playground/lib/python3.10/site-packages (from smolagents[litellm]) (0.28.1)
# Requirement already satisfied: requests>=2.32.3 in ./playground/lib/python3.10/site-packages (from smolagents[litellm]) (2.32.3)
# Requirement already satisfied: rich>=13.9.4 in ./playground/lib/python3.10/site-packages (from smolagents[litellm]) (13.9.4)
# Requirement already satisfied: pandas>=2.2.3 in ./playground/lib/python3.10/site-packages (from smolagents[litellm]) (2.2.3)
# Requirement already satisfied: jinja2>=3.1.4 in ./playground/lib/python3.10/site-packages (from smolagents[litellm]) (3.1.5)
# Requirement already satisfied: pillow>=11.0.0 in ./playground/lib/python3.10/site-packages (from smolagents[litellm]) (11.1.0)
# Requirement already satisfied: markdownify>=0.14.1 in ./playground/lib/python3.10/site-packages (from smolagents[litellm]) (1.0.0)
# Requirement already satisfied: duckduckgo-search>=6.3.7 in ./playground/lib/python3.10/site-packages (from smolagents[litellm]) (7.5.0)
# Requirement already satisfied: python-dotenv in ./playground/lib/python3.10/site-packages (from smolagents[litellm]) (1.0.1)
# Collecting litellm>=1.60.2 (from smolagents[litellm])
#   Downloading litellm-1.63.0-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: click>=8.1.8 in ./playground/lib/python3.10/site-packages (from duckduckgo-search>=6.3.7->smolagents[litellm]) (8.1.8)
# Requirement already satisfied: primp>=0.14.0 in ./playground/lib/python3.10/site-packages (from duckduckgo-search>=6.3.7->smolagents[litellm]) (0.14.0)
# Requirement already satisfied: lxml>=5.3.0 in ./playground/lib/python3.10/site-packages (from duckduckgo-search>=6.3.7->smolagents[litellm]) (5.3.1)
# Requirement already satisfied: filelock in ./playground/lib/python3.10/site-packages (from huggingface-hub>=0.28.0->smolagents[litellm]) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in ./playground/lib/python3.10/site-packages (from huggingface-hub>=0.28.0->smolagents[litellm]) (2025.2.0)
# Requirement already satisfied: packaging>=20.9 in ./playground/lib/python3.10/site-packages (from huggingface-hub>=0.28.0->smolagents[litellm]) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in ./playground/lib/python3.10/site-packages (from huggingface-hub>=0.28.0->smolagents[litellm]) (6.0.2)
# Requirement already satisfied: tqdm>=4.42.1 in ./playground/lib/python3.10/site-packages (from huggingface-hub>=0.28.0->smolagents[litellm]) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./playground/lib/python3.10/site-packages (from huggingface-hub>=0.28.0->smolagents[litellm]) (4.12.2)
# Requirement already satisfied: MarkupSafe>=2.0 in ./playground/lib/python3.10/site-packages (from jinja2>=3.1.4->smolagents[litellm]) (3.0.2)
# Requirement already satisfied: aiohttp in ./playground/lib/python3.10/site-packages (from litellm>=1.60.2->smolagents[litellm]) (3.11.13)
# Requirement already satisfied: httpx>=0.23.0 in ./playground/lib/python3.10/site-packages (from litellm>=1.60.2->smolagents[litellm]) (0.28.1)
# Collecting importlib-metadata>=6.8.0 (from litellm>=1.60.2->smolagents[litellm])
#   Downloading importlib_metadata-8.6.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in ./playground/lib/python3.10/site-packages (from litellm>=1.60.2->smolagents[litellm]) (4.23.0)
# Collecting openai>=1.61.0 (from litellm>=1.60.2->smolagents[litellm])
#   Downloading openai-1.65.4-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in ./playground/lib/python3.10/site-packages (from litellm>=1.60.2->smolagents[litellm]) (2.10.6)
# Collecting tiktoken>=0.7.0 (from litellm>=1.60.2->smolagents[litellm])
#   Downloading tiktoken-0.9.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Collecting tokenizers (from litellm>=1.60.2->smolagents[litellm])
#   Downloading tokenizers-0.21.0-cp39-abi3-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Requirement already satisfied: beautifulsoup4<5,>=4.9 in ./playground/lib/python3.10/site-packages (from markdownify>=0.14.1->smolagents[litellm]) (4.13.3)
# Requirement already satisfied: six<2,>=1.15 in ./playground/lib/python3.10/site-packages (from markdownify>=0.14.1->smolagents[litellm]) (1.17.0)
# Requirement already satisfied: numpy>=1.22.4 in ./playground/lib/python3.10/site-packages (from pandas>=2.2.3->smolagents[litellm]) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./playground/lib/python3.10/site-packages (from pandas>=2.2.3->smolagents[litellm]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./playground/lib/python3.10/site-packages (from pandas>=2.2.3->smolagents[litellm]) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in ./playground/lib/python3.10/site-packages (from pandas>=2.2.3->smolagents[litellm]) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./playground/lib/python3.10/site-packages (from requests>=2.32.3->smolagents[litellm]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in ./playground/lib/python3.10/site-packages (from requests>=2.32.3->smolagents[litellm]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./playground/lib/python3.10/site-packages (from requests>=2.32.3->smolagents[litellm]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./playground/lib/python3.10/site-packages (from requests>=2.32.3->smolagents[litellm]) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./playground/lib/python3.10/site-packages (from rich>=13.9.4->smolagents[litellm]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./playground/lib/python3.10/site-packages (from rich>=13.9.4->smolagents[litellm]) (2.19.1)
# Requirement already satisfied: soupsieve>1.2 in ./playground/lib/python3.10/site-packages (from beautifulsoup4<5,>=4.9->markdownify>=0.14.1->smolagents[litellm]) (2.6)
# Requirement already satisfied: anyio in ./playground/lib/python3.10/site-packages (from httpx>=0.23.0->litellm>=1.60.2->smolagents[litellm]) (4.8.0)
# Requirement already satisfied: httpcore==1.* in ./playground/lib/python3.10/site-packages (from httpx>=0.23.0->litellm>=1.60.2->smolagents[litellm]) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in ./playground/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.23.0->litellm>=1.60.2->smolagents[litellm]) (0.14.0)
# Collecting zipp>=3.20 (from importlib-metadata>=6.8.0->litellm>=1.60.2->smolagents[litellm])
#   Downloading zipp-3.21.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=22.2.0 in ./playground/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.60.2->smolagents[litellm]) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./playground/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.60.2->smolagents[litellm]) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in ./playground/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.60.2->smolagents[litellm]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in ./playground/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.60.2->smolagents[litellm]) (0.22.3)
# Requirement already satisfied: mdurl~=0.1 in ./playground/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->smolagents[litellm]) (0.1.2)
# Collecting distro<2,>=1.7.0 (from openai>=1.61.0->litellm>=1.60.2->smolagents[litellm])
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting jiter<1,>=0.4.0 (from openai>=1.61.0->litellm>=1.60.2->smolagents[litellm])
#   Downloading jiter-0.8.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Requirement already satisfied: sniffio in ./playground/lib/python3.10/site-packages (from openai>=1.61.0->litellm>=1.60.2->smolagents[litellm]) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in ./playground/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.0->litellm>=1.60.2->smolagents[litellm]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in ./playground/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.0->litellm>=1.60.2->smolagents[litellm]) (2.27.2)
# Collecting regex>=2022.1.18 (from tiktoken>=0.7.0->litellm>=1.60.2->smolagents[litellm])
#   Downloading regex-2024.11.6-cp310-cp310-macosx_11_0_arm64.whl.metadata (40 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./playground/lib/python3.10/site-packages (from aiohttp->litellm>=1.60.2->smolagents[litellm]) (2.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in ./playground/lib/python3.10/site-packages (from aiohttp->litellm>=1.60.2->smolagents[litellm]) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in ./playground/lib/python3.10/site-packages (from aiohttp->litellm>=1.60.2->smolagents[litellm]) (4.0.3)
# Requirement already satisfied: frozenlist>=1.1.1 in ./playground/lib/python3.10/site-packages (from aiohttp->litellm>=1.60.2->smolagents[litellm]) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./playground/lib/python3.10/site-packages (from aiohttp->litellm>=1.60.2->smolagents[litellm]) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in ./playground/lib/python3.10/site-packages (from aiohttp->litellm>=1.60.2->smolagents[litellm]) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./playground/lib/python3.10/site-packages (from aiohttp->litellm>=1.60.2->smolagents[litellm]) (1.18.3)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./playground/lib/python3.10/site-packages (from anyio->httpx>=0.23.0->litellm>=1.60.2->smolagents[litellm]) (1.2.2)
# Downloading litellm-1.63.0-py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 24.7 MB/s eta 0:00:00a 0:00:01
# Downloading importlib_metadata-8.6.1-py3-none-any.whl (26 kB)
# Downloading openai-1.65.4-py3-none-any.whl (473 kB)
# Downloading tiktoken-0.9.0-cp310-cp310-macosx_11_0_arm64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 23.5 MB/s eta 0:00:00
# Downloading tokenizers-0.21.0-cp39-abi3-macosx_11_0_arm64.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 27.7 MB/s eta 0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.8.2-cp310-cp310-macosx_11_0_arm64.whl (311 kB)
# Downloading regex-2024.11.6-cp310-cp310-macosx_11_0_arm64.whl (284 kB)
# Downloading zipp-3.21.0-py3-none-any.whl (9.6 kB)
# Installing collected packages: zipp, regex, jiter, distro, tiktoken, importlib-metadata, tokenizers, openai, litellm
# Successfully installed distro-1.9.0 importlib-metadata-8.6.1 jiter-0.8.2 litellm-1.63.0 openai-1.65.4 regex-2024.11.6 tiktoken-0.9.0 tokenizers-0.21.0 zipp-3.21.0

# %%
import os
from langchain.docstore.document import Document
from langchain.text_splitter import RecursiveCharacterTextSplitter
from smolagents import Tool
from langchain_community.retrievers import BM25Retriever
from smolagents import CodeAgent, HfApiModel, LiteLLMModel

class PartyPlanningRetrieverTool(Tool):
    name = "party_planning_retriever"
    description = "Uses semantic search to retrieve relevant party planning ideas for Alfred’s superhero-themed party at Wayne Manor."
    inputs = {
        "query": {
            "type": "string",
            "description": "The query to perform. This should be a query related to party planning or superhero themes.",
        }
    }
    output_type = "string"

    def __init__(self, docs, **kwargs):
        super().__init__(**kwargs)
        self.retriever = BM25Retriever.from_documents(
            docs, k=5  # Retrieve the top 5 documents
        )

    def forward(self, query: str) -> str:
        assert isinstance(query, str), "Your search query must be a string"

        docs = self.retriever.invoke(
            query,
        )
        return "\nRetrieved ideas:\n" + "".join(
            [
                f"\n\n===== Idea {str(i)} =====\n" + doc.page_content
                for i, doc in enumerate(docs)
            ]
        )

# Simulate a knowledge base about party planning
party_ideas = [
    {"text": "A superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains.", "source": "Party Ideas 1"},
    {"text": "Hire a professional DJ who can play themed music for superheroes like Batman and Wonder Woman.", "source": "Entertainment Ideas"},
    {"text": "For catering, serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.'", "source": "Catering Ideas"},
    {"text": "Decorate with iconic superhero logos and projections of Gotham and other superhero cities around the venue.", "source": "Decoration Ideas"},
    {"text": "Interactive experiences with VR where guests can engage in superhero simulations or compete in themed games.", "source": "Entertainment Ideas"}
]

source_docs = [
    Document(page_content=doc["text"], metadata={"source": doc["source"]})
    for doc in party_ideas
]

# Split the documents into smaller chunks for more efficient search
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50,
    add_start_index=True,
    strip_whitespace=True,
    separators=["\n\n", "\n", ".", " ", ""],
)
docs_processed = text_splitter.split_documents(source_docs)

# Create the retriever tool
party_planning_retriever = PartyPlanningRetrieverTool(docs_processed)

# Initialize the agent
model = LiteLLMModel(model_id="gemini/gemini-2.0-flash-lite", api_key=os.getenv(key="GEMINI_API_KEY"))
agent = CodeAgent(model=model, tools=[party_planning_retriever])
# agent = CodeAgent(tools=[party_planning_retriever], model=HfApiModel()) Fail with You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly 

# Example usage
response = agent.run(
    "Find ideas for a luxury superhero-themed party, including entertainment, catering, and decoration options."
)

print(response)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Find ideas for a luxury superhero-themed party, including entertainment, catering, and decoration options.      │
# │                                                                                                                 │
# ╰─ LiteLLMModel - gemini/gemini-2.0-flash-lite ───────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   entertainment_ideas = party_planning_retriever(query="luxury superhero party entertainment")
#   print(f"Entertainment ideas: {entertainment_ideas}")
#   catering_ideas = party_planning_retriever(query="luxury superhero party catering")
#   print(f"Catering ideas: {catering_ideas}")
#   decoration_ideas = party_planning_retriever(query="luxury superhero party decorations")
#   print(f"Decoration ideas: {decoration_ideas}")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Entertainment ideas:
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# A superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains.
#
# ===== Idea 1 =====
# Decorate with iconic superhero logos and projections of Gotham and other superhero cities around the venue.
#
# ===== Idea 2 =====
# Interactive experiences with VR where guests can engage in superhero simulations or compete in themed games.
#
# ===== Idea 3 =====
# For catering, serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.'
#
# ===== Idea 4 =====
# Hire a professional DJ who can play themed music for superheroes like Batman and Wonder Woman.
# Catering ideas:
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# A superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains.
#
# ===== Idea 1 =====
# Decorate with iconic superhero logos and projections of Gotham and other superhero cities around the venue.
#
# ===== Idea 2 =====
# Interactive experiences with VR where guests can engage in superhero simulations or compete in themed games.
#
# ===== Idea 3 =====
# For catering, serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.'
#
# ===== Idea 4 =====
# Hire a professional DJ who can play themed music for superheroes like Batman and Wonder Woman.
# Decoration ideas:
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# A superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains.
#
# ===== Idea 1 =====
# Decorate with iconic superhero logos and projections of Gotham and other superhero cities around the venue.
#
# ===== Idea 2 =====
# Interactive experiences with VR where guests can engage in superhero simulations or compete in themed games.
#
# ===== Idea 3 =====
# For catering, serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.'
#
# ===== Idea 4 =====
# Hire a professional DJ who can play themed music for superheroes like Batman and Wonder Woman.
#
# Out: None
# [Step 0: Duration 9.06 seconds| Input tokens: 2,264 | Output tokens: 146]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   final_answer(f"Here are some ideas for a luxury superhero-themed party:\n\nEntertainment:\n- A superhero-themed
#   masquerade ball with interactive experiences with VR. \n- Hire a professional DJ who can play themed
#   music.\n\nCatering:\n- Serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's
#   Power Steak.\n\nDecoration:\n- Decorate with iconic superhero logos and projections of Gotham and other
#   superhero cities around the venue, with gold accents and velvet curtains.")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Out - Final answer: Here are some ideas for a luxury superhero-themed party:
#
# Entertainment:
# - A superhero-themed masquerade ball with interactive experiences with VR.
# - Hire a professional DJ who can play themed music.
#
# Catering:
# - Serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.
#
# Decoration:
# - Decorate with iconic superhero logos and projections of Gotham and other superhero cities around the venue, with
# gold accents and velvet curtains.
# [Step 1: Duration 1.53 seconds| Input tokens: 5,253 | Output tokens: 296]
# Here are some ideas for a luxury superhero-themed party:
#
# Entertainment:
# - A superhero-themed masquerade ball with interactive experiences with VR.
# - Hire a professional DJ who can play themed music.
#
# Catering:
# - Serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.
#
# Decoration:
# - Decorate with iconic superhero logos and projections of Gotham and other superhero cities around the venue, with gold accents and velvet curtains.

# %% [markdown]
# This enhanced agent can:
#
# First check the documentation for relevant information
# Combine insights from the knowledge base
# Maintain conversation context through memory
